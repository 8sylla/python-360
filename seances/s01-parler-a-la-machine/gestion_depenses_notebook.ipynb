# %% [markdown]
# # Gestionnaire de Dépenses — Notebook de pratique
# ### Chapitre 1 : Python Basics (Automate the Boring Stuff)
#
# Ce notebook applique **uniquement** les notions du chapitre 1 :
# expressions, opérateurs, types (`int`, `float`, `str`), variables, `print()`, `input()`,
# `len()`, `str()`/`int()`/`float()`, `type()`, `round()`, `abs()`.
#
# **Règle du jeu** : chaque section a
# 1. un exercice à coder (`# TODO`),
# 2. un ou plusieurs **pièges** — devinez le résultat AVANT d'exécuter,
# 3. une correction juste après (ne la lisez qu'après avoir essayé !).
#
# Exécutez les cellules dans l'ordre.

# %% [markdown]
# ## Section 1 — Variables & types
# Une dépense a un **nom** (`str`), un **montant** (`float`) et une **catégorie** (`str`).

# %%
# TODO : crée trois variables décrivant une dépense
# depense_nom      -> "Courses"
# depense_montant  -> 45.90
# depense_categorie -> "Alimentation"

depense_nom = ...
depense_montant = ...
depense_categorie = ...

print(depense_nom, depense_montant, depense_categorie)

# %% [markdown]
# ### Piège — prédisez AVANT d'exécuter
# ```python
# montant = "50"
# total = montant + 20
# ```
# Qu'affiche ce code ?

# %%
# Essayez le piège ici (ça doit planter — c'est normal !)
montant = "50"
total = montant + 20

# %% [markdown]
# **Correction** : `montant` est une **chaîne** (`"50"`), pas un nombre.
# `"50" + 20` mélange `str` et `int` → `TypeError`.
# Il faut convertir : `int(montant) + 20` → `70`.

# %%
# Version corrigée
montant = "50"
total = int(montant) + 20
print(total)

# %% [markdown]
# ## Section 2 — Opérations arithmétiques
# On a une liste de dépenses de la semaine (on utilisera des variables séparées, pas encore de listes — hors programme du chapitre 1).

# %%
lundi = 12.50
mardi = 8.0
mercredi = 25.99
jeudi = 0.0
vendredi = 40.0

# TODO : calcule le total de la semaine
total_semaine = ...
print("Total de la semaine :", total_semaine)

# TODO : calcule la moyenne journalière (5 jours)
moyenne = ...
print("Moyenne par jour :", moyenne)

# %% [markdown]
# ### Piège — type du résultat
# ```python
# total_semaine = 12 + 8 + 26  # que des int
# moyenne = total_semaine / 5
# type(moyenne)
# ```
# `int / int` donne-t-il un `int` ou un `float` ?

# %%
total_semaine = 12 + 8 + 26
moyenne = total_semaine / 5
print(moyenne, type(moyenne))

# %% [markdown]
# **Correction** : `/` renvoie **toujours** un `float`, même si le résultat est "rond".
# Pour une division entière (ex: répartir un total en parts entières), on utilise `//`.

# %%
# TODO : Un groupe de 3 amis doit se partager une facture de 47 euros
# à parts entières égales, et garder le reste pour un pourboire.
facture = 47

part_par_personne = ...   # utilise //
reste_pourboire = ...     # utilise %

print("Chacun paie :", part_par_personne)
print("Reste en pourboire :", reste_pourboire)

# %% [markdown]
# ### Piège — priorité des opérateurs (type entretien)
# Sans exécuter, que vaut :
# ```python
# prix = 10 + 5 * 2 - 3 ** 2
# ```

# %%
prix = 10 + 5 * 2 - 3 ** 2
print(prix)  # devine avant de lancer !

# %% [markdown]
# ## Section 3 — Chaînes de caractères : reçu de caisse
# On veut construire un petit "ticket de caisse" texte.

# %%
article = "Cafe"
prix_unitaire = 3.5
quantite = 2

# TODO : construis la ligne de ticket avec + (concaténation)
# format voulu : "Cafe x2 : 3.5 EUR/u"
ligne = ...
print(ligne)

# %% [markdown]
# ### Piège — le classique des entretiens Python
# ```python
# total = 7.0
# print("Total : " + total + " EUR")
# ```

# %%
total = 7.0
print("Total : " + total + " EUR")

# %% [markdown]
# **Correction** : on ne peut pas concaténer `str` et `float` directement.
# Il faut `str(total)`.

# %%
total = 7.0
print("Total : " + str(total) + " EUR")

# %%
# TODO : utilise la réplication de chaîne (*) pour dessiner
# une ligne de séparation de 20 tirets sous le ticket
separateur = ...
print(separateur)

# %% [markdown]
# ### Piège — réplication invalide
# ```python
# separateur = "-" * 2.0
# ```
# Pourquoi ça plante alors que `"-" * 20` fonctionne ?

# %%
separateur = "-" * 2.0

# %% [markdown]
# ## Section 4 — `input()` et conversions
# `input()` renvoie **toujours** une chaîne de caractères, même si l'utilisateur tape un nombre.
# Exécutez la cellule suivante et tapez un montant, par exemple `15.5`.

# %%
montant_saisi = input("Montant de la dépense (EUR) : ")
print("Type reçu :", type(montant_saisi))

# %% [markdown]
# ### Piège — oublier la conversion
# ```python
# montant_saisi = input("Montant : ")  # utilisateur tape 15.5
# double = montant_saisi * 2
# ```
# Que fait `* 2` sur une chaîne ? Un TypeError, ou autre chose ?

# %%
montant_saisi = "15.5"   # on simule la saisie pour éviter d'attendre une entrée
double = montant_saisi * 2
print(double)

# %% [markdown]
# **Piège subtil** : ça ne plante **pas** ! `"15.5" * 2` fait de la réplication de chaîne
# → `"15.515.5"`, pas `31.0`. C'est un piège très fréquent en entretien car il ne lève **aucune erreur**,
# juste un résultat silencieusement faux.
#
# Correction :

# %%
montant_saisi = "15.5"
double = float(montant_saisi) * 2
print(double)

# %%
# TODO : demande à l'utilisateur son budget mensuel (str),
# convertis-le en float, et calcule le budget hebdomadaire (budget / 4)
budget_saisi = input("Budget mensuel (EUR) : ")
budget_mensuel = ...     # conversion
budget_hebdo = ...
print("Budget hebdomadaire :", budget_hebdo)

# %% [markdown]
# ### Piège — conversion impossible
# ```python
# int("12.90")
# ```
# Pourquoi ça plante alors que `int(12.90)` fonctionne très bien ?

# %%
int("12.90")

# %% [markdown]
# ## Section 5 — `len()`, `round()`, `abs()`

# %%
# TODO : vérifie que le nom d'une dépense ne dépasse pas 20 caractères
nom_depense = "Abonnement salle de sport mensuel"
longueur = ...
print("Longueur :", longueur)
print("Nom trop long ?", longueur > 20)

# %%
# TODO : arrondis ces montants à 2 décimales avec round()
prix_brut = 19.4567
prix_arrondi = ...
print(prix_arrondi)

# %% [markdown]
# ### Piège — arrondi bancaire
# Sans exécuter, que valent :
# ```python
# round(0.5)
# round(1.5)
# round(2.5)
# ```

# %%
print(round(0.5), round(1.5), round(2.5))

# %% [markdown]
# **Correction** : Python arrondit les `.5` vers l'entier **pair** le plus proche
# (*banker's rounding*) : `0`, `2`, `2`. Ce n'est **pas** l'arrondi "classique" (toujours vers le haut) !

# %%
# TODO : un remboursement a été saisi par erreur en négatif (-25.0)
# corrige le montant pour qu'il soit toujours positif, avec abs()
remboursement = -25.0
remboursement_corrige = ...
print(remboursement_corrige)

# %% [markdown]
# ### Piège — mauvais nombre d'arguments
# ```python
# abs(-10, -20)
# ```

# %%
abs(-10, -20)

# %% [markdown]
# ## Section 6 — Mini-projet : Gestionnaire de dépenses complet
# Combine tout ce qui précède dans un mini-programme.
# Complète les `TODO`. Le programme doit :
# 1. Demander 3 dépenses (nom + montant) à l'utilisateur.
# 2. Convertir chaque montant en `float`.
# 3. Calculer le total et la moyenne.
# 4. Arrondir le total à 2 décimales.
# 5. Afficher un petit reçu avec une ligne de séparation (`*`).

# %%
# --- Mini-projet : à compléter ---

print("=== Gestionnaire de dépenses ===")

# Dépense 1
nom_1 = input("Nom de la dépense 1 : ")
montant_1_str = input("Montant de la dépense 1 : ")
montant_1 = ...   # TODO conversion en float

# Dépense 2
nom_2 = input("Nom de la dépense 2 : ")
montant_2_str = input("Montant de la dépense 2 : ")
montant_2 = ...   # TODO conversion en float

# Dépense 3
nom_3 = input("Nom de la dépense 3 : ")
montant_3_str = input("Montant de la dépense 3 : ")
montant_3 = ...   # TODO conversion en float

total = ...              # TODO somme des 3 montants
total_arrondi = ...       # TODO round() à 2 décimales
moyenne = ...              # TODO total / 3

separateur = "*" * 25
print(separateur)
print(nom_1 + " : " + str(montant_1) + " EUR")
print(nom_2 + " : " + str(montant_2) + " EUR")
print(nom_3 + " : " + str(montant_3) + " EUR")
print(separateur)
print("TOTAL : " + str(total_arrondi) + " EUR")
print("Moyenne : " + str(round(moyenne, 2)) + " EUR")

# %% [markdown]
# ### Auto-test (sans passer par `input`)
# Vérifie ta logique de calcul avec des valeurs fixes, grâce à `assert`
# (si rien ne s'affiche, c'est gagné — sinon Python lève une `AssertionError`).

# %%
def total_et_moyenne(m1, m2, m3):
    total = m1 + m2 + m3
    moyenne = total / 3
    return round(total, 2), round(moyenne, 2)

# TODO : appelle ta fonction avec (10.5, 20.25, 5.0) et vérifie le résultat
resultat = total_et_moyenne(10.5, 20.25, 5.0)
assert resultat == (35.75, 11.92), f"Résultat obtenu : {resultat}"
print("Tous les tests passent ✅")

# %% [markdown]
# ## Section 7 — Quiz éclair (style entretien technique)
# Pour chaque bloc : **prédisez le résultat ou l'erreur**, puis exécutez pour vérifier.

# %%
# Quiz 1
print(type(10 / 2))

# %%
# Quiz 2
print('3' * 3)

# %%
# Quiz 3
print(3 * 3.0 == 9)

# %%
# Quiz 4
x = 5
x = x + 1
y = x
x = x + 1
print(x, y)

# %%
# Quiz 5 — attention, ça plante volontairement
prix = "12" + 3

# %%
# Quiz 6
print(round(-2.5))

# %% [markdown]
# ### Corrigés du quiz
# 1. `<class 'float'>` — `/` renvoie toujours un float.
# 2. `'333'` — réplication de chaîne, pas multiplication numérique.
# 3. `True` — `9.0 == 9` est vrai en Python (comparaison entre int et float sur la valeur).
# 4. `6 6` — `y` copie la **valeur** de `x` au moment de l'affectation, pas une référence qui suivrait les changements futurs.
# 5. `TypeError: can only concatenate str (not "int") to str` — il fallait `int("12") + 3` ou `"12" + str(3)`.
# 6. `-2` — arrondi bancaire, `.5` va vers l'entier pair le plus proche (ici `-2`, pas `-3`).

# %% [markdown]
# ## Pour aller plus loin
# - Recommencez le mini-projet en ajoutant une **catégorie** par dépense.
# - Cherchez ce que fait `bin()` et `hex()` (extra credit du chapitre 1) et testez-les sur vos montants convertis en `int`.
# - Notez tous les messages d'erreur que vous rencontrez : `SyntaxError`, `TypeError`, `ValueError` — savoir les reconnaître au premier coup d'œil est une compétence clé en entretien.
